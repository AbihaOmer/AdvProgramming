# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 572  573    2016     Raipur  2016-05-22     Delhi Daredevils
# 573  574    2016  Bangalore  2016-05-24        Gujarat Lions
# 574  575    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 575  576    2016      Delhi  2016-05-27        Gujarat Lions
# 576  577    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 572  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 573  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 574        Kolkata Knight Riders        Kolkata Knight Riders         field
# 575          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 576  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 572  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.sample()
# Out:
#     id  season    city        date                        team1  \
# 67  68    2009  Durban  2009-04-24  Royal Challengers Bangalore
#
#               team2                  toss_winner toss_decision  result  \
# 67  Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#     dl_applied           winner  win_by_runs  win_by_wickets player_of_match  \
# 67           0  Kings XI Punjab            0               7       RS Bopara
#
#         venue      umpire1         umpire2  umpire3
# 67  Kingsmead  BR Doctrove  TH Wijewardene      NaN

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df["team1"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions'], dtype=object)

# %%
import pandas as pd
import numpy as np

# %%
#url
url='https://raw.githubusercontent.com/Tanishqa-10/AskPython/main/Sampledata.csv'
data=pd.read_csv(url)
data
# Out:
#       Name Last Name Member         City Code  Amount
# 0      Jim       Doe     No         Ohio   JD    8075
# 1     Gill  McGinnis    Yes        Texas   GM    9119
# 2      Joe    Repici    Yes       Bostan   JR    8075
# 3  Stephen     Tyler     No           LA   ST   91234
# 4    Oscar  Blankman     No          NYC   OB     298
# 5    Kelly       Jet     No  Desert City   KJ     123

# %%
#excel
# !pip install openpyxl

# %%
data=pd.read_excel('SaleData.xlsx')

data
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
df[["winner","season","city"]]
# Out:
#                           winner  season        city
# 0          Kolkata Knight Riders    2008   Bangalore
# 1            Chennai Super Kings    2008  Chandigarh
# 2               Delhi Daredevils    2008       Delhi
# 3    Royal Challengers Bangalore    2008      Mumbai
# 4          Kolkata Knight Riders    2008     Kolkata
# ..                           ...     ...         ...
# 572  Royal Challengers Bangalore    2016      Raipur
# 573  Royal Challengers Bangalore    2016   Bangalore
# 574          Sunrisers Hyderabad    2016       Delhi
# 575          Sunrisers Hyderabad    2016       Delhi
# 576          Sunrisers Hyderabad    2016   Bangalore
#
# [577 rows x 3 columns]

# %%
df[["winner","season","city"]].shape
# Out:
# (577, 3)

# %%
df.shape
# Out:
# (577, 18)

# %%
df.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
df.iloc[[0,9,19,29]]
# Out:
#     id  season        city        date                  team1  \
# 0    1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 9   10    2008  Chandigarh  2008-04-25        Kings XI Punjab
# 19  20    2008     Chennai  2008-05-02    Chennai Super Kings
# 29  30    2008      Jaipur  2008-05-09        Deccan Chargers
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 9                Mumbai Indians               Mumbai Indians         field
# 19             Delhi Daredevils          Chennai Super Kings           bat
# 29             Rajasthan Royals             Rajasthan Royals         field
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0   normal           0  Kolkata Knight Riders          140               0
# 9   normal           0        Kings XI Punjab           66               0
# ...

# %%
df.iloc[1:11]
# Out:
#     id  season        city        date                        team1  \
# 1    2    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 2    3    2008       Delhi  2008-04-19             Rajasthan Royals
# 3    4    2008      Mumbai  2008-04-20               Mumbai Indians
# 4    5    2008     Kolkata  2008-04-20              Deccan Chargers
# 5    6    2008      Jaipur  2008-04-21              Kings XI Punjab
# 6    7    2008   Hyderabad  2008-04-22              Deccan Chargers
# 7    8    2008     Chennai  2008-04-23          Chennai Super Kings
# 8    9    2008   Hyderabad  2008-04-24              Deccan Chargers
# 9   10    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 10  11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
#
#                           team2          toss_winner toss_decision  result  \
# 1               Kings XI Punjab  Chennai Super Kings           bat  normal
# ...

# %%
df.iloc[0:11:2]
# Out:
#     id  season       city        date                        team1  \
# 0    1    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 2    3    2008      Delhi  2008-04-19             Rajasthan Royals
# 4    5    2008    Kolkata  2008-04-20              Deccan Chargers
# 6    7    2008  Hyderabad  2008-04-22              Deccan Chargers
# 8    9    2008  Hyderabad  2008-04-24              Deccan Chargers
# 10  11    2008  Bangalore  2008-04-26  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2              Delhi Daredevils             Rajasthan Royals           bat
# 4         Kolkata Knight Riders              Deccan Chargers           bat
# 6              Delhi Daredevils              Deccan Chargers           bat
# 8              Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
df.iloc[ : ,[1,5,6]]
# Out:
#      season                        team2                  toss_winner
# 0      2008  Royal Challengers Bangalore  Royal Challengers Bangalore
# 1      2008              Kings XI Punjab          Chennai Super Kings
# 2      2008             Delhi Daredevils             Rajasthan Royals
# 3      2008  Royal Challengers Bangalore               Mumbai Indians
# 4      2008        Kolkata Knight Riders              Deccan Chargers
# ..      ...                          ...                          ...
# 572    2016  Royal Challengers Bangalore  Royal Challengers Bangalore
# 573    2016  Royal Challengers Bangalore  Royal Challengers Bangalore
# 574    2016        Kolkata Knight Riders        Kolkata Knight Riders
# 575    2016          Sunrisers Hyderabad          Sunrisers Hyderabad
# 576    2016  Royal Challengers Bangalore          Sunrisers Hyderabad
#
# [577 rows x 3 columns]

# %%
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
find =df["city"]=="hyderabad"
find
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# Name: city, Length: 577, dtype: bool

# %%
find =df["city"]=="Hyderabad"
find
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 572    False
# 573    False
# 574    False
# 575    False
# 576    False
# Name: city, Length: 577, dtype: bool

# %%
df[find].shape
# Out:
# (41, 18)

# %%
df[find].shape[0]
# Out:
# 41

# %%
mask1 = df['city']=='Hyderabad'
mask2 = df['date']>'2010-01-01'

# %%
df[mask1 & mask2].shape[0]
# Out:
# 34

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
def get_city_match_count(city):
    mask=df['city']==city
    return df[mask].shape[0]

# %%
city = input("enter city : ")
get_city_match_count(city)
# Out:
# enter city :  Bangalore
# 58

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions'],
#       dtype=object)

# %%
df['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df['winner'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 80
# Chennai Super Kings            79
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Rajasthan Royals               63
# Kings XI Punjab                63
# Delhi Daredevils               56
# Sunrisers Hyderabad            34
# Deccan Chargers                29
# Pune Warriors                  12
# Gujarat Lions                   9
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
type(df['winner'].value_counts())
# Out:
# pandas.core.series.Series

# %%
myseries = df['winner'].value_counts()
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Pune Warriors', 'Gujarat Lions', 'Kochi Tuskers Kerala',
#        'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
myseries.values
# Out:
# array([80, 79, 70, 68, 63, 63, 56, 34, 29, 12,  9,  6,  5], dtype=int64)

# %%
df["team1"].value_counts()
# Out:
# team1
# Chennai Super Kings            77
# Mumbai Indians                 76
# Kings XI Punjab                69
# Kolkata Knight Riders          62
# Royal Challengers Bangalore    62
# Delhi Daredevils               57
# Rajasthan Royals               54
# Deccan Chargers                43
# Sunrisers Hyderabad            37
# Pune Warriors                  20
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Gujarat Lions                   6
# Name: count, dtype: int64

# %%
df['team1'].value_counts()+df['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               133
# Gujarat Lions                   16
# Kings XI Punjab                134
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          132
# Mumbai Indians                 140
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    139
# Sunrisers Hyderabad             62
# Name: count, dtype: int64

# %%
(df['team1'].value_counts()+df['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# Chennai Super Kings            131
# Rajasthan Royals               118
# Deccan Chargers                 75
# Sunrisers Hyderabad             62
# Pune Warriors                   46
# Gujarat Lions                   16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
(df['team1'].value_counts()+df['team2'].value_counts()).sort_values(ascending=False).head()
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# Name: count, dtype: int64

# %%
data=df['team1'].value_counts()+df['team2'].value_counts()

# %%
data.sort_values(ascending=False).head()
# Out:
# Mumbai Indians                 140
# Royal Challengers Bangalore    139
# Kings XI Punjab                134
# Delhi Daredevils               133
# Kolkata Knight Riders          132
# Name: count, dtype: int64

# %%
data.sort_values(ascending=False).tail()
# Out:
# Sunrisers Hyderabad        62
# Pune Warriors              46
# Gujarat Lions              16
# Kochi Tuskers Kerala       14
# Rising Pune Supergiants    14
# Name: count, dtype: int64

# %%
df.sort_values("city")
# Out:
#       id  season       city        date                        team1  \
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 415  416    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
df.sort_values(["city"],ascending=True)
# Out:
#       id  season       city        date                        team1  \
# 401  402    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 398  399    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 415  416    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 417  418    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                    team2            toss_winner toss_decision  result  \
# ...

# %%
df.sort_values('date')
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.sort_values(["date","city"])
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 416  417    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 411  412    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 412  413    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 405  406    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 400  401    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 409  410    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 410  411    2014        NaN  2014-04-25               Mumbai Indians
# 407  408    2014        NaN  2014-04-23          Chennai Super Kings
# 402  403    2014        NaN  2014-04-19               Mumbai Indians
# 403  404    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.sort_values(['city','date'],ascending=[False,False])
# Out:
#       id  season           city        date                  team1  \
# 569  570    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 565  566    2016  Visakhapatnam  2016-05-17       Delhi Daredevils
# 563  564    2016  Visakhapatnam  2016-05-15         Mumbai Indians
# 559  560    2016  Visakhapatnam  2016-05-13         Mumbai Indians
# 556  557    2016  Visakhapatnam  2016-05-10    Sunrisers Hyderabad
# ..   ...     ...            ...         ...                    ...
# 409  410    2014            NaN  2014-04-25    Sunrisers Hyderabad
# 410  411    2014            NaN  2014-04-25         Mumbai Indians
# 407  408    2014            NaN  2014-04-23    Chennai Super Kings
# 402  403    2014            NaN  2014-04-19         Mumbai Indians
# 403  404    2014            NaN  2014-04-19  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 569      Rising Pune Supergiants              Kings XI Punjab           bat
# ...

# %%
# Drop Duplicates Method
df.city.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 572     True
# 573     True
# 574     True
# 575     True
# 576     True
# Name: city, Length: 577, dtype: bool

# %%
df.city.duplicated().sum()
# Out:
# 546

# %%
df.id.duplicated().sum()
# Out:
# 0

# %%
df.dl_applied.duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 572     True
# 573     True
# 574     True
# 575     True
# 576     True
# Name: dl_applied, Length: 577, dtype: bool

# %%
df.loc[df.city.duplicated(keep='first'),:]
# Out:
#       id  season        city        date                        team1  \
# 8      9    2008   Hyderabad  2008-04-24              Deccan Chargers
# 9     10    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 10    11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 12    13    2008      Mumbai  2008-04-27               Mumbai Indians
# ..   ...     ...         ...         ...                          ...
# 572  573    2016      Raipur  2016-05-22             Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24                Gujarat Lions
# 574  575    2016       Delhi  2016-05-25          Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27                Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.loc[df.city.duplicated(),:]
# Out:
#       id  season        city        date                        team1  \
# 8      9    2008   Hyderabad  2008-04-24              Deccan Chargers
# 9     10    2008  Chandigarh  2008-04-25              Kings XI Punjab
# 10    11    2008   Bangalore  2008-04-26  Royal Challengers Bangalore
# 11    12    2008     Chennai  2008-04-26        Kolkata Knight Riders
# 12    13    2008      Mumbai  2008-04-27               Mumbai Indians
# ..   ...     ...         ...         ...                          ...
# 572  573    2016      Raipur  2016-05-22             Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24                Gujarat Lions
# 574  575    2016       Delhi  2016-05-25          Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27                Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.city.duplicated().shape
# Out:
# (577,)

# %%
df.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
df.drop_duplicates(subset=['city']).shape[0]
# Out:
# 31

# %%
df.drop_duplicates(subset=['city','season']).shape
# Out:
# (97, 18)

# %%
df.drop_duplicates('season',keep='last')
# Out:
#       id  season          city        date                team1  \
# 57    58    2008        Mumbai  2008-06-01  Chennai Super Kings
# 114  115    2009  Johannesburg  2009-05-24      Deccan Chargers
# 174  175    2010        Mumbai  2010-04-25  Chennai Super Kings
# 247  248    2011       Chennai  2011-05-28  Chennai Super Kings
# 321  322    2012       Chennai  2012-05-27  Chennai Super Kings
# 397  398    2013       Kolkata  2013-05-26       Mumbai Indians
# 457  458    2014     Bangalore  2014-06-01      Kings XI Punjab
# 516  517    2015       Kolkata  2015-05-24       Mumbai Indians
# 576  577    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 57              Rajasthan Royals             Rajasthan Royals         field
# 114  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 174               Mumbai Indians          Chennai Super Kings           bat
# ...

# %%
df.drop_duplicates('season',keep='first')
# Out:
#       id  season       city        date                  team1  \
# 0      1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 58    59    2009  Cape Town  2009-04-18         Mumbai Indians
# 115  116    2010     Mumbai  2010-03-12  Kolkata Knight Riders
# 175  176    2011    Chennai  2011-04-08    Chennai Super Kings
# 248  249    2012    Chennai  2012-04-04    Chennai Super Kings
# 322  323    2013    Kolkata  2013-04-03       Delhi Daredevils
# 398  399    2014  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 458  459    2015    Kolkata  2015-04-08         Mumbai Indians
# 517  518    2016     Mumbai  2016-04-09         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 58           Chennai Super Kings          Chennai Super Kings         field
# 115              Deccan Chargers              Deccan Chargers         field
# ...

# %%
df.drop_duplicates('season',keep='first')[['season','winner']]
# Out:
#      season                   winner
# 0      2008    Kolkata Knight Riders
# 58     2009           Mumbai Indians
# 115    2010    Kolkata Knight Riders
# 175    2011      Chennai Super Kings
# 248    2012           Mumbai Indians
# 322    2013    Kolkata Knight Riders
# 398    2014    Kolkata Knight Riders
# 458    2015    Kolkata Knight Riders
# 517    2016  Rising Pune Supergiants

# %%
df.drop_duplicates('season',keep='first')[['season','team1','team2','winner']]
# Out:
#      season                  team1                        team2  \
# 0      2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 58     2009         Mumbai Indians          Chennai Super Kings
# 115    2010  Kolkata Knight Riders              Deccan Chargers
# 175    2011    Chennai Super Kings        Kolkata Knight Riders
# 248    2012    Chennai Super Kings               Mumbai Indians
# 322    2013       Delhi Daredevils        Kolkata Knight Riders
# 398    2014  Kolkata Knight Riders               Mumbai Indians
# 458    2015         Mumbai Indians        Kolkata Knight Riders
# 517    2016         Mumbai Indians      Rising Pune Supergiants
#
#                       winner
# 0      Kolkata Knight Riders
# 58            Mumbai Indians
# 115    Kolkata Knight Riders
# 175      Chennai Super Kings
# 248           Mumbai Indians
# 322    Kolkata Knight Riders
# 398    Kolkata Knight Riders
# 458    Kolkata Knight Riders
# 517  Rising Pune Supergiants

# %%
# Group Function in Pandas
company = pd.read_csv('customer.csv',index_col=0)

# %%
company
# Out:
#                    Title  Employees                      Sector  \
# Rank
# 1                Walmart    2300000                   Retailing
# 2     Berkshire Hathaway     367700                  Financials
# 3                  Apple     116000                  Technology
# 4            Exxon Mobil      72700                      Energy
# 5               McKesson      68000                 Wholesalers
# ...                  ...        ...                         ...
# 496        Michaels Cos.      31000                   Retailing
# 497        Toll Brothers       4200  Engineering & Construction
# 498                Yahoo       8500                  Technology
# 499        Vistra Energy       4431                      Energy
# 500       ABM Industries     110000           Business Services
#
#                                       Industry         Hqlocation  Revenues  \
# Rank
# 1                        General Merchandisers    Bentonville, AR    485873
# ...

# %%
company.head()
# Out:
#                    Title  Employees       Sector  \
# Rank
# 1                Walmart    2300000    Retailing
# 2     Berkshire Hathaway     367700   Financials
# 3                  Apple     116000   Technology
# 4            Exxon Mobil      72700       Energy
# 5               McKesson      68000  Wholesalers
#
#                                       Industry         Hqlocation  Revenues  \
# Rank
# 1                        General Merchandisers    Bentonville, AR    485873
# 2     Insurance: Property and Casualty (Stock)          Omaha, NE    223604
# 3                  Computers, Office Equipment      Cupertino, CA    215639
# 4                           Petroleum Refining         Irving, TX    205004
# 5                     Wholesalers: Health Care  San Francisco, CA    192487
#
#       Profits
# Rank
# 1     13643.0
# 2     24074.0
# 3     45687.0
# 4      7840.0
# 5      2258.0

# %%
company.tail()
# Out:
#                Title  Employees                      Sector  \
# Rank
# 496    Michaels Cos.      31000                   Retailing
# 497    Toll Brothers       4200  Engineering & Construction
# 498            Yahoo       8500                  Technology
# 499    Vistra Energy       4431                      Energy
# 500   ABM Industries     110000           Business Services
#
#                               Industry     Hqlocation  Revenues  Profits
# Rank
# 496         Specialty Retailers: Other     Irving, TX      5197    378.2
# 497                       Homebuilders    Horsham, PA      5170    382.1
# 498    Internet Services and Retailing  Sunnyvale, CA      5169   -214.3
# 499                             Energy     Dallas, TX      5164   -214.3
# 500   Diversified Outsourcing Services   New York, NY      5145     57.2

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 1 to 500
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       500 non-null    object
#  1   Employees   500 non-null    int64
#  2   Sector      500 non-null    object
#  3   Industry    500 non-null    object
#  4   Hqlocation  500 non-null    object
#  5   Revenues    500 non-null    int64
#  6   Profits     500 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 31.2+ KB

# %%
company.describe()
# Out:
#           Employees       Revenues       Profits
# count  5.000000e+02     500.000000    500.000000
# mean   5.635013e+04   24111.748000   1779.479800
# std    1.234520e+05   38337.353337   3937.558721
# min    8.300000e+01    5145.000000  -6177.000000
# 25%    1.190000e+04    7245.000000    235.725000
# 50%    2.500000e+04   11384.000000    683.600000
# 75%    5.682525e+04   22605.250000   1770.775000
# max    2.300000e+06  485873.000000  45687.000000

# %%
company.columns
# Out:
# Index(['Title', 'Employees', 'Sector', 'Industry', 'Hqlocation', 'Revenues',
#        'Profits'],
#       dtype='object')
